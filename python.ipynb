# %% [markdown]
# <a href="https://colab.research.google.com/github/18013033/data_mining/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install requests
! pip install pandas
! pip install matplotlib
! pip install numpy
! pip install seaborn

# %%
import pandas as pd
from google.colab import files
filenya = files.upload()
# Out:
#      <input type="file" id="files-d51458d0-bd1e-4bd2-9efb-51596602dd8b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d51458d0-bd1e-4bd2-9efb-51596602dd8b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filenya
# Out:
# {'Algorithm_data_mentah.csv': b' Pendapatan ,Produk, Harga ,Jumlah , Total ,Tingkat Kepuasan\r\n" IDR 600,000.00 ",A," IDR 3,000.00 ",4," IDR 12,000.00 ",Puas\r\n" IDR 1,200,000.00 ",D," IDR 6,000.00 ",4," IDR 24,000.00 ",Cukup Puas\r\n" IDR 950,000.00 ",D," IDR 6,000.00 ",3," IDR 18,000.00 ",Puas\r\n" IDR 400,000.00 ",A," IDR 3,000.00 ",2," IDR 6,000.00 ",Puas\r\n" IDR 1,200,000.00 ",D," IDR 6,000.00 ",4," IDR 24,000.00 ",Cukup Puas\r\n" IDR 800,000.00 ",B," IDR 4,000.00 ",4," IDR 16,000.00 ",Puas\r\n" IDR 950,000.00 ",B," IDR 4,000.00 ",5," IDR 20,000.00 ",Tidak Puas\r\n" IDR 1,100,000.00 ",A," IDR 3,000.00 ",3," IDR 9,000.00 ",Puas\r\n" IDR 800,000.00 ",A," IDR 3,000.00 ",2," IDR 6,000.00 ",Tidak Puas\r\n" IDR 1,700,000.00 ",A," IDR 3,000.00 ",5," IDR 15,000.00 ",Puas\r\n" IDR 600,000.00 ",A," IDR 3,000.00 ",4," IDR 12,000.00 ",Puas\r\n" IDR 950,000.00 ",B," IDR 4,000.00 ",5," IDR 20,000.00 ",Puas\r\n" IDR 400,000.00 ",C," IDR 5,000.00 ",1," IDR 5,000.00 ",Cukup Puas\r\n" IDR 6,45
# ...

# %%
import io
df = pd.read_csv(io.StringIO(filenya['Algorithm_data_mentah.csv'].decode('utf-8')))
print(df)
# Out:
#            Pendapatan  Produk          Harga   Jumlah            Total   \
# 0      IDR 600,000.00       A   IDR 3,000.00         4   IDR 12,000.00
# 1    IDR 1,200,000.00       D   IDR 6,000.00         4   IDR 24,000.00
# 2      IDR 950,000.00       D   IDR 6,000.00         3   IDR 18,000.00
# 3      IDR 400,000.00       A   IDR 3,000.00         2    IDR 6,000.00
# 4    IDR 1,200,000.00       D   IDR 6,000.00         4   IDR 24,000.00
# ..                 ...    ...             ...      ...              ...
# 95     IDR 950,000.00       B   IDR 4,000.00         5   IDR 20,000.00
# 96   IDR 1,100,000.00       A   IDR 3,000.00         3    IDR 9,000.00
# 97     IDR 800,000.00       A   IDR 3,000.00         2    IDR 6,000.00
# 98   IDR 1,700,000.00       A   IDR 3,000.00         5   IDR 15,000.00
# 99     IDR 600,000.00       A   IDR 3,000.00         4   IDR 12,000.00
#
#    Tingkat Kepuasan
# 0              Puas
# 1        Cukup Puas
# 2              Puas
# 3              Puas
# ...

# %%
df.head()
# Out:
#           Pendapatan  Produk          Harga   Jumlah            Total   \
# 0     IDR 600,000.00       A   IDR 3,000.00         4   IDR 12,000.00
# 1   IDR 1,200,000.00       D   IDR 6,000.00         4   IDR 24,000.00
# 2     IDR 950,000.00       D   IDR 6,000.00         3   IDR 18,000.00
# 3     IDR 400,000.00       A   IDR 3,000.00         2    IDR 6,000.00
# 4   IDR 1,200,000.00       D   IDR 6,000.00         4   IDR 24,000.00
#
#   Tingkat Kepuasan
# 0             Puas
# 1       Cukup Puas
# 2             Puas
# 3             Puas
# 4       Cukup Puas
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_273738584260457348 = autoviz.get_registered_df('df_273738584260457348')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
# ...

# %%
df.head()
# Out:
#           Pendapatan  Produk          Harga   Jumlah            Total   \
# 0     IDR 600,000.00       A   IDR 3,000.00         4   IDR 12,000.00
# 1   IDR 1,200,000.00       D   IDR 6,000.00         4   IDR 24,000.00
# 2     IDR 950,000.00       D   IDR 6,000.00         3   IDR 18,000.00
# 3     IDR 400,000.00       A   IDR 3,000.00         2    IDR 6,000.00
# 4   IDR 1,200,000.00       D   IDR 6,000.00         4   IDR 24,000.00
#
#   Tingkat Kepuasan
# 0             Puas
# 1       Cukup Puas
# 2             Puas
# 3             Puas
# 4       Cukup Puas
